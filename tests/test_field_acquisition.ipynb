# %%
import logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s - %(message)s')

# %%
import pandas as pd

# %%
from agActor.field_acquisition import acquire_field
from pfs.utils.datamodel.ag import AutoGuiderStarMask

# %%
agc_exposure_id = 755735
pfs_design_id = 7970990036001222325

# %%
kwargs = dict(magnitude=20, max_size=200, min_size=-1, max_ellipticity=1)

# %% [markdown]
# ## is_guide = False (default)

# %%
guide_offsets = acquire_field(design_id=pfs_design_id, frame_id=agc_exposure_id, altazimuth=True, **kwargs)
# Out:
# INFO - Calling acquire_field with frame_id=755735, obswl=0.62, altazimuth=True kwargs={'magnitude': 20, 'max_size': 200, 'min_size': -1, 'max_ellipticity': 1}
# INFO - Getting detected objects from opdb.agc_data
# INFO - Created database opdb with dsn=None
# INFO - Calculating detector plane coordinates for detected objects
# INFO - Calculating major and minor semi axes for detected objects
# INFO - Detected objects: 757
# INFO - get_guide_objects: taken_at=Timestamp('2025-06-18 21:25:56+0000', tz='UTC'),inr=np.float64(-69.96712),adc=np.float64(17.13),m2_pos3=np.float64(4.694298)
# INFO - Getting guide_objects from opdb via design_id=7970990036001222325
# INFO - Got 1452 guide objects, renaming columns
# INFO - Guide objects before filtering (is_guide=False): 1452
# INFO - Filtered 0 galaxies from results.
# INFO - Guide objects after filtering: 1452
# INFO - Using ra=np.float64(276.7916667),dec=np.float64(6.3280556),inst_pa=np.float64(0.0)
# INFO - Final values for calculating offsets: ra=np.float64(276.7916667),dec=np.float64(6.3280556),inst_pa=np.float64(0.0),inr=np.float64(-69.96712)
# INFO - Calling calculate_guide_offsets with _kwargs={'max_size': 200, 'min_size': -1, 'max_ellipticity': 1}
# INFO - Using obstime=Timestamp('2025-06-18 21:25:56+0000', tz='UTC') for calculating offsets
# INFO - Calling calculate_acquisition_offsets (old FAinstpa) with _kwargs={'maxsize': 200.0, 'minsize': -1.0, 'maxellip': 1.0}
# INFO - Guide object before filtering: 1452
# INFO - Guide objects after filtering: 1452
# INFO - Filtering 757 detected objects with maxellip=1.0 maxsize=200.0 minsize=-1.0
# INFO - Found 757 detected sources after filtering
# INFO - Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Final Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Matched sources with valid residuals: 665
# INFO - Initial median distance: 8.14e-02
# INFO - calculate_acquisition_offsets (old FAinstpa): ra_offset=np.float64(-0.4848332672707553),dec_offset=np.float64(-0.27264590971534375),inr_offset=np.float64(2.730207868487357),scale_offset=np.float64(-0.0009076032970649776)
# INFO - alt=np.float64(-54.90123965991071),az=np.float64(315.88232554791296),dalt=np.float64(-0.5241569109756483),daz=np.float64(0.31594448969372024)
# INFO - Identified objects: 757 Number valid: 665
# INFO - Converting ra_offset, dec_offset to arcsec: ra_offset=np.float64(-0.4848332672707553),dec_offset=np.float64(-0.27264590971534375)
# INFO - Converting offsets to pixels: dx=np.float64(0.4818792283579843),dy=np.float64(-0.27264590971534375)
# INFO - Calculated star stats: flux=np.float64(8592.764),peak=np.float64(289.90076),size=np.float64(0.6292029553710495)

# %%
guide_objects_df = pd.DataFrame(guide_offsets.guide_objects)
detected_objects_df = pd.DataFrame(guide_offsets.detected_objects)
identified_objects_df = pd.DataFrame(guide_offsets.identified_objects)

# %%
# Show only the identified objects that were marked as GOOD.
good_guide_objects_idx = guide_objects_df.query('filtered_by == 0').sort_values(by=['agc_camera_id', 'x_dp', 'y_dp']).index
identified_objects_df.query('guide_object_id in @good_guide_objects_idx and valid_residual == 1')
# Out:
#      detected_object_id  guide_object_id  detected_object_x_mm  \
# 0                     0             1372            246.567634
# 1                     1             1435            246.550552
# 3                     3             1450            246.494140
# 4                     4             1381            246.346485
# 5                     5             1450            246.116010
# ..                  ...              ...                   ...
# 752                 752              687            113.119650
# 753                 753              739            117.073402
# 754                 754              688            114.222417
# 755                 755              746            115.999837
# 756                 756              690            115.203329
#
#      detected_object_y_mm  guide_object_x_mm  guide_object_y_mm  \
# 0                1.782835         246.987890           1.933321
# 1                0.927971         246.470705           0.536534
# 3                3.797579         246.527536           4.004595
# 4                3.084445         246.768169           3.241343
# 5                3.850372         246.527536           4.004595
# ..                    ...                ...                ...
# 752           -206.877226         113.172466        -207.216867
# 753           -203.977434         117.141027        -204.309301
# 754           -205.327421         114.279998        -205.665769
# 755           -204.213543         116.063428        -204.549399
# 756           -204.545622         115.262744        -204.880430
#
#      detected_object_x_pix  detected_object_y_pix  guide_object_x_pix  \
# 0                367.96118              36.013283          356.528450
# 1                433.71347              37.618084          463.796579
# 3                212.95738              40.981335          197.044591
# 4                267.76306              52.581850          255.837559
# 5                208.76778              70.049995          197.044591
# ..                     ...                    ...                 ...
# 752              953.76996             942.147640          963.213446
# 753              579.02280             984.793900          587.180495
# 754              820.94930            1003.522600          830.025153
# 755              659.72614            1010.025100          668.305583
# 756              725.59400            1018.267760          734.412253
#
#      guide_object_y_pix  agc_camera_id     err_x     err_y   resid_x  \
# 0              3.635024              0 -0.420256 -0.150485 -0.223174
# 1             43.893272              0  0.079847  0.391437  0.276473
# 3             38.342014              0 -0.033396 -0.207016  0.163283
# 4             20.091547              0 -0.421684 -0.156898 -0.224794
# 5             38.342014              0 -0.411526 -0.154223 -0.214847
# ..                  ...            ...       ...       ...       ...
# 752          917.451287              5 -0.052816  0.339642  0.022640
# 753          960.051179              5 -0.067625  0.331867  0.011475
# 754          978.730699              5 -0.057581  0.338347  0.018901
# 755          985.170100              5 -0.063590  0.335856  0.014527
# 756          993.642215              5 -0.059415  0.334808  0.017971
#
#       resid_y  valid_residual
# 0   -0.196533            True
# 1    0.344147            True
# 3   -0.251188            True
# 4   -0.201763            True
# 5   -0.198395            True
# ..        ...             ...
# 752  0.104285            True
# 753  0.099179            True
# 754  0.104431            True
# 755  0.102960            True
# 756  0.101613            True
#
# [665 rows x 16 columns]

# %%
guide_objects_df['filter_flag_name'] = guide_objects_df.filtered_by.map(lambda x: AutoGuiderStarMask(x).name)
guide_objects_df.loc[guide_objects_df.filtered_by == 0, 'filter_flag_name'] = 'GOOD'

# %%
guide_objects_df.filter_flag_name.value_counts()
# Out:
# filter_flag_name
# GOOD    1452
# Name: count, dtype: int64

# %% [markdown]
# ## is_guide = True

# %%
guide_offsets = acquire_field(design_id=pfs_design_id, frame_id=agc_exposure_id, altazimuth=True, is_guide=True, **kwargs)
# Out:
# INFO - Calling acquire_field with frame_id=755735, obswl=0.62, altazimuth=True kwargs={'magnitude': 20, 'max_size': 200, 'min_size': -1, 'max_ellipticity': 1}
# INFO - Getting detected objects from opdb.agc_data
# INFO - Calculating detector plane coordinates for detected objects
# INFO - Calculating major and minor semi axes for detected objects
# INFO - Detected objects: 757
# INFO - get_guide_objects: taken_at=Timestamp('2025-06-18 21:25:56+0000', tz='UTC'),inr=np.float64(-69.96712),adc=np.float64(17.13),m2_pos3=np.float64(4.694298)
# INFO - Getting guide_objects from opdb via design_id=7970990036001222325
# INFO - Got 1452 guide objects, renaming columns
# INFO - Guide objects before filtering (is_guide=True): 1452
# INFO - Filtered 0 galaxies from results.
# INFO - Filtering non NON_BINARY, removes 223 guide objects.
# INFO - Filtering non GAIA, removes 0 guide objects.
# INFO - Filtering non PHOTO_SIG, removes 0 guide objects.
# INFO - Filtering non ASTROMETRIC, removes 372 guide objects.
# INFO - Filtering non PMRA, removes 199 guide objects.
# INFO - Filtering non PMDEC, removes 199 guide objects.
# INFO - Filtering non PARA, removes 199 guide objects.
# INFO - Guide objects after filtering: 1003
# INFO - Using ra=np.float64(276.7916667),dec=np.float64(6.3280556),inst_pa=np.float64(0.0)
# INFO - Final values for calculating offsets: ra=np.float64(276.7916667),dec=np.float64(6.3280556),inst_pa=np.float64(0.0),inr=np.float64(-69.96712)
# INFO - Calling calculate_guide_offsets with _kwargs={'max_size': 200, 'min_size': -1, 'max_ellipticity': 1}
# INFO - Using obstime=Timestamp('2025-06-18 21:25:56+0000', tz='UTC') for calculating offsets
# INFO - Calling calculate_acquisition_offsets (old FAinstpa) with _kwargs={'maxsize': 200.0, 'minsize': -1.0, 'maxellip': 1.0}
# INFO - Guide object before filtering: 1452
# INFO - Guide objects after filtering: 1003
# INFO - Filtering 757 detected objects with maxellip=1.0 maxsize=200.0 minsize=-1.0
# INFO - Found 757 detected sources after filtering
# INFO - Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Final Rejection threshold: 0.5 mm (limit 0.5 mm)
# INFO - Matched sources with valid residuals: 598
# INFO - Initial median distance: 6.22e-02
# INFO - calculate_acquisition_offsets (old FAinstpa): ra_offset=np.float64(-0.3186691268376786),dec_offset=np.float64(-0.17195437834126928),inr_offset=np.float64(9.098131311951759),scale_offset=np.float64(-0.0011544237260750494)
# INFO - alt=np.float64(-54.90123965991071),az=np.float64(315.88232554791296),dalt=np.float64(-0.3390629937968015),daz=np.float64(0.21599858234822022)
# INFO - Identified objects: 757 Number valid: 598
# INFO - Converting ra_offset, dec_offset to arcsec: ra_offset=np.float64(-0.3186691268376786),dec_offset=np.float64(-0.17195437834126928)
# INFO - Converting offsets to pixels: dx=np.float64(0.316727508833047),dy=np.float64(-0.17195437834126928)
# INFO - Calculated star stats: flux=np.float64(20432.307),peak=np.float64(587.28613),size=np.float64(0.6089210489941247)

# %%
guide_objects_df = pd.DataFrame(guide_offsets.guide_objects)
detected_objects_df = pd.DataFrame(guide_offsets.detected_objects)
identified_objects_df = pd.DataFrame(guide_offsets.identified_objects)

# %%
# Show only the identified objects that were marked as GOOD.
good_guide_objects_idx = guide_objects_df.query('filtered_by == 0').sort_values(by=['agc_camera_id', 'x_dp', 'y_dp']).index
identified_objects_df.query('guide_object_id in @good_guide_objects_idx and valid_residual == 1')
# Out:
#      detected_object_id  guide_object_id  detected_object_x_mm  \
# 0                     0             1372            246.567634
# 1                     1             1430            246.550552
# 3                     3             1450            246.494140
# 4                     4             1381            246.346485
# 5                     5             1450            246.116010
# ..                  ...              ...                   ...
# 752                 752              687            113.119650
# 753                 753              739            117.073402
# 754                 754              688            114.222417
# 755                 755              746            115.999837
# 756                 756              690            115.203329
#
#      detected_object_y_mm  guide_object_x_mm  guide_object_y_mm  \
# 0                1.782835         246.987890           1.933321
# 1                0.927971         246.967117           1.077214
# 3                3.797579         246.527536           4.004595
# 4                3.084445         246.768169           3.241343
# 5                3.850372         246.527536           4.004595
# ..                    ...                ...                ...
# 752           -206.877226         113.172466        -207.216867
# 753           -203.977434         117.141027        -204.309301
# 754           -205.327421         114.279998        -205.665769
# 755           -204.213543         116.063428        -204.549399
# 756           -204.545622         115.262744        -204.880430
#
#      detected_object_x_pix  detected_object_y_pix  guide_object_x_pix  \
# 0                367.96118              36.013283          356.528450
# 1                433.71347              37.618084          422.375071
# 3                212.95738              40.981335          197.044591
# 4                267.76306              52.581850          255.837559
# 5                208.76778              70.049995          197.044591
# ..                     ...                    ...                 ...
# 752              953.76996             942.147640          963.213446
# 753              579.02280             984.793900          587.180495
# 754              820.94930            1003.522600          830.025153
# 755              659.72614            1010.025100          668.305583
# 756              725.59400            1018.267760          734.412253
#
#      guide_object_y_pix  agc_camera_id     err_x     err_y   resid_x  \
# 0              3.635024              0 -0.420256 -0.150485 -0.152144
# 1              5.524167              0 -0.416565 -0.149243 -0.148508
# 3             38.342014              0 -0.033396 -0.207016  0.234267
# 4             20.091547              0 -0.421684 -0.156898 -0.153775
# 5             38.342014              0 -0.411526 -0.154223 -0.143863
# ..                  ...            ...       ...       ...       ...
# 752          917.451287              5 -0.052816  0.339642  0.053246
# 753          960.051179              5 -0.067625  0.331867  0.043150
# 754          978.730699              5 -0.057581  0.338347  0.049828
# 755          985.170100              5 -0.063590  0.335856  0.045929
# 756          993.642215              5 -0.059415  0.334808  0.049165
#
#       resid_y  valid_residual
# 0   -0.188428            True
# 1   -0.188168            True
# 3   -0.242553            True
# 4   -0.193325            True
# 5   -0.189760            True
# ..        ...             ...
# 752  0.065314            True
# 753  0.060774            True
# 754  0.065792            True
# 755  0.064531            True
# 756  0.063130            True
#
# [598 rows x 16 columns]

# %%
guide_objects_df['filter_flag_name'] = guide_objects_df.filtered_by.map(lambda x: AutoGuiderStarMask(x).name)
guide_objects_df.loc[guide_objects_df.filtered_by == 0, 'filter_flag_name'] = 'GOOD'

# %%
guide_objects_df.filter_flag_name.value_counts()
# Out:
# filter_flag_name
# GOOD                                      1003
# ASTROMETRIC                                226
# PMRA|PMDEC|PARA|ASTROMETRIC|NON_BINARY     125
# PMRA|PMDEC|PARA|NON_BINARY                  74
# ASTROMETRIC|NON_BINARY                      21
# NON_BINARY                                   3
# Name: count, dtype: int64
